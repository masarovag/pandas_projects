# %%
import pandas as pd

# %%
bigmac = pd.read_csv("bigmac.csv").dropna(how = "any")
bigmac["Date"] = pd.to_datetime(bigmac["Date"])
bigmac.sort_values("Price in US Dollars")
pd.set_option('display.max_rows', None) 
bigmac
# Out:
#           Date         Country  Price in US Dollars
# 0   2016-01-01       Argentina                 2.39
# 1   2016-01-01       Australia                 3.74
# 2   2016-01-01          Brazil                 3.35
# 3   2016-01-01         Britain                 4.22
# 4   2016-01-01          Canada                 4.14
# 5   2016-01-01           Chile                 2.94
# 6   2016-01-01           China                 2.68
# 7   2016-01-01        Colombia                 2.43
# 8   2016-01-01      Costa Rica                 4.02
# 9   2016-01-01  Czech Republic                 2.98
# 10  2016-01-01         Denmark                 4.32
# 11  2016-01-01           Egypt                 2.16
# 12  2016-01-01       Euro area                 4.00
# 13  2016-01-01       Hong Kong                 2.48
# 14  2016-01-01         Hungary                 3.08
# 15  2016-01-01           India                 1.90
# 16  2016-01-01       Indonesia                 2.19
# ...
